# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:/Users/harsh/Downloads/dataset.csv")

# %%
data
# Out:
#                                                   email  category
# 0     URL: http://www.newsisfree.com/click/-1,817167...  not-spam
# 1     On Thu, 19 Sep 2002, Bill Stoddard wrote:\n\n-...  not-spam
# 2     Dan Kohn <dan@dankohn.com> writes:\n\n\n\n> Gu...  not-spam
# 3     wintermute wrote:\n\n>>Anyone know where in Ir...  not-spam
# 4     I attended the same conference, and was impres...  not-spam
# ...                                                 ...       ...
# 3791  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...      spam
# 3792  <html>\n\n<HEAD> \n\n<TITLE>creditfix</TITLE> ...      spam
# 3793  Hello:\n\n\n\nAre you satisfied with your ISP?...      spam
# 3794  <html><HEAD><TITLE>creditfix</TITLE> \n\n</HEA...      spam
# 3795  <HTML><HEAD></HEAD><BODY><b><FONT SIZE=3D4>In ...      spam
#
# [3796 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3796 entries, 0 to 3795
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   email     3796 non-null   object
#  1   category  3796 non-null   object
# dtypes: object(2)
# memory usage: 59.4+ KB

# %%
data.head()
# Out:
#                                                email  category
# 0  URL: http://www.newsisfree.com/click/-1,817167...  not-spam
# 1  On Thu, 19 Sep 2002, Bill Stoddard wrote:\n\n-...  not-spam
# 2  Dan Kohn <dan@dankohn.com> writes:\n\n\n\n> Gu...  not-spam
# 3  wintermute wrote:\n\n>>Anyone know where in Ir...  not-spam
# 4  I attended the same conference, and was impres...  not-spam

# %%
data.tail()
# Out:
#                                                   email category
# 3791  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...     spam
# 3792  <html>\n\n<HEAD> \n\n<TITLE>creditfix</TITLE> ...     spam
# 3793  Hello:\n\n\n\nAre you satisfied with your ISP?...     spam
# 3794  <html><HEAD><TITLE>creditfix</TITLE> \n\n</HEA...     spam
# 3795  <HTML><HEAD></HEAD><BODY><b><FONT SIZE=3D4>In ...     spam

# %%
# data.loc[data['category']=='spam','category',]=0
# data.loc[data['category']=='not-spam','category',]=1

# %%
X= data['email']
Y= data['category']

# %%
X
# Out:
# 0       URL: http://www.newsisfree.com/click/-1,817167...
# 1       On Thu, 19 Sep 2002, Bill Stoddard wrote:\n\n-...
# 2       Dan Kohn <dan@dankohn.com> writes:\n\n\n\n> Gu...
# 3       wintermute wrote:\n\n>>Anyone know where in Ir...
# 4       I attended the same conference, and was impres...
#                               ...
# 3791    <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# 3792    <html>\n\n<HEAD> \n\n<TITLE>creditfix</TITLE> ...
# 3793    Hello:\n\n\n\nAre you satisfied with your ISP?...
# 3794    <html><HEAD><TITLE>creditfix</TITLE> \n\n</HEA...
# 3795    <HTML><HEAD></HEAD><BODY><b><FONT SIZE=3D4>In ...
# Name: email, Length: 3796, dtype: object

# %%
Y
# Out:
# 0       not-spam
# 1       not-spam
# 2       not-spam
# 3       not-spam
# 4       not-spam
#           ...
# 3791        spam
# 3792        spam
# 3793        spam
# 3794        spam
# 3795        spam
# Name: category, Length: 3796, dtype: object

# %%
print(X.shape)
print(Y.shape)
# Out:
# (3796,)
# (3796,)

# %%
from  sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (3796,)
# (3036,)
# (760,)

# %%
print(Y.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (3796,)
# (3036,)
# (760,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
feature_extraction=TfidfVectorizer(min_df=1,stop_words='english')
X_train_features=feature_extraction.fit_transform(X_train)
X_test_features=feature_extraction.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()
model.fit(X_train_features,Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score
prediction_on_training_data=model.predict(X_train_features)
accuracy_on_training_data=accuracy_score(Y_train,prediction_on_training_data)
print("ACCURACY ON TRAINING:",accuracy_on_training_data)
# Out:
# ACCURACY ON TRAINING: 0.9930830039525692

# %%
prediction_on_test_data=model.predict(X_test_features)
accuracy_on_test_data=accuracy_score(Y_test,prediction_on_test_data)
print("ACCURACY ON TEST:",accuracy_on_test_data)
# Out:
# ACCURACY ON TEST: 0.9842105263157894

# %%
input_email=[""" Subject: Follow-Up: Project Timeline and Next Steps

Body:
Dear John Doe,

I hope you’re doing well. I wanted to follow up regarding the Data Science project and share an update on the current timeline and next steps.

Current Progress
We’ve successfully completed the following:

Data Collection – Gathered and cleaned the data from the FakeNewsNet dataset.
Exploratory Data Analysis (EDA) – Performed an initial analysis to understand the structure and trends in the data.
Next Steps
As we move forward, here are the upcoming tasks and deadlines:

Feature Engineering: Expected completion by January 10th.
Model Training: Kick-off scheduled for January 15th.
Request for Input
To ensure smooth progress, it would be helpful to get your feedback on the following:

Any additional features you’d like to consider for the model.
Preferred machine learning algorithms for the classification task.
Additional Notes
Please let me know if there are any adjustments or additional priorities to consider as we proceed. I’m happy to discuss this in more detail if needed.

Thank you for your continued support and guidance. Looking forward to your feedback!

Best regards,
Harsh Mishra
MSc Data Science Student








"""]

input_data_features=feature_extraction.transform(input_email)
prediction=model.predict(input_data_features)

print(prediction)
# Out:
# ['not-spam']

# %%
input_email=[ """ Dear Sir/Madam,
I hope this message finds you well. My name is Sean Webb, and I am reaching out from the UK. Our company is currently seeking a reliable agent to oversee the supply of raw materials to our firm.
If you are interested in this opportunity and believe you can manage the project effectively, please respond to this email, for more details.
Sincerely,
Sean Webb.

"""]

input_data_features=feature_extraction.transform(input_email)
prediction=model.predict(input_data_features)

print(prediction)
# Out:
# ['spam']
